# %% [markdown]
# # 20 Questions on Hotel Database Cleaning & Date Operations

# %% [markdown]
# # Data Cleaning Questions

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('arbor_hotel_data_pandas.csv')

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %%
#1. How do you fill missing values in the Rating column with the value "Medium"?
df['Rating'].fillna('Medium', inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4996\2648201156.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna('Medium', inplace = True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4996\2648201156.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Medium' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Rating'].fillna('Medium', inplace = True)

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %%
#2.	Replace missing values in the HotelName column with "Guest".
df['HotelName'] = df['HotelName'].fillna('Guest')

# %%
#verify-- check missing value after 
df['HotelName'].value_counts()
# Out:
# HotelName
# Mountain Inn         26
# Royal Stay           21
# City Lights Hotel    19
# Grand Palace         18
# Ocean View           16
# Name: count, dtype: int64

# %% [raw]
# ✅ Step 1 — Check value counts BEFORE filling
# df['HotelName'].value_counts(dropna=False)
#
#
# Using dropna=False lets you SEE the missing values (NaN) clearly.

# %%
#OR-- verify
df['HotelName'].isna().sum()  #this Confirm no NaN left
# Out:
# 0

# %% [markdown]
# 2. .isna()
#
# Checks every value in that column.
#
# Returns True if the value is missing (NaN), otherwise False.
#
# Example:

# %% [markdown]
# | HotelName         | isna() |
# | ----------------- | ------ |
# | City Lights Hotel | False  |
# | NaN               | True   |
# | Ocean View        | False  |

# %% [markdown]
# So isna() converts the column into a list of True/False values.
#
# 3. .sum()
#
# When you sum boolean values:
#
# True = 1
#
# False = 0
#
# So summing up True values gives the total number of missing values.

# %%
#3. Identify and remove any duplicate records from the dataset.
#Step 1 — Identify duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# What this does:
#
# df.duplicated() returns True for every row that is a duplicate.
#
# .sum() counts all duplicates.
#
# This tells you how many duplicate rows exist.

# %%
#step 2. View the duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [HotelID, HotelName, Location, RoomType, Rating, PricePerNight, BookingStatus, CheckInDate]
# Index: []

# %%
#Step 3 — Remove duplicates
df.drop_duplicates(inplace = True)

# %%
#Optional: Remove duplicates based on specific columns
#Sometimes duplicates may occur only by HotelName/Location/etc.
df.drop_duplicates(subset = ['HotelName', 'Location'], inplace = True)

# %%
#4.	Convert the CheckInDate column to a proper datetime format.
#step 1. Check column dtype:
df['CheckInDate'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ✅ What dtype('0') means
#
# Normally, df['CheckInDate'].dtype should return something like:
#
# dtype('O') → Object (string)
#
# dtype('int64') → Integer
#
# dtype('float64') → Float
#
# dtype('<M8[ns]') → Datetime
#
# dtype('0') is not a valid pandas dtype
#
# This usually happens if:
#
# The column contains mixed types or corrupted data.
#
# The column was misread when importing (e.g., from CSV).
#
# The dataset was manually entered, and pandas couldn’t infer the type.

# %%
#✅ How to fix / investigate
#Step 1 — Check the first few values

df['CheckInDate'].head(10)
# Out:
# 0     03:16.8
# 1     03:16.8
# 2     03:16.8
# 3     03:16.8
# 5     03:16.8
# 6     03:16.8
# 9     03:16.8
# 10    03:16.8
# 12    03:16.8
# 13    03:16.8
# Name: CheckInDate, dtype: object

# %%
#Step 2 — Check unique values
# This will tell you the patterns in the column.
df['CheckInDate'].unique()
# Out:
# array(['03:16.8'], dtype=object)

# %%
#Step 3 — Convert to string first (safe step)
#This ensures pandas treats it as string/object before converting to datetime.
df['CheckInDate'] =df['CheckInDate'].astype(str)

# %% [markdown]
# ✅ 1. Why do we convert to string first?
#
# You wrote:
#
# df['CheckInDate'] = df['CheckInDate'].astype(str)
#
#
# ✔ Yes — this is correct.
# We do this because your column had a strange dtype (dtype('0')), meaning pandas could not understand it.
#
# Converting to string ensures:
#
# The entire column has a consistent type
#
# Conversion to datetime becomes safe
#
# Pandas won’t break or throw weird errors
#
# So YES — this step is good.

# %%
#Step 4 — Convert to datetime
#If the column contains something like 03:16.8 (time), you can convert it with a custom format:
df['CheckInDate'] = pd.to_datetime(df['CheckInDate'], format = '%H:%M:%S', errors = 'coerce')

# %% [raw]
# ✅ Meaning of errors='coerce'
#
# In pandas:
#
# pd.to_datetime(column, errors='coerce')
#
#
# means:
#
# 🔹 If the value can be converted → convert it
# 🔹 If the value CANNOT be converted → make it NaT (missing datetime)
#
# ⭐ So errors='coerce' is used for SAFE conversion.
#
# It prevents your program from crashing and instead gives NaT for invalid values.
#
# 📌 Summary
# ✔ Yes — converting to string first is correct
# ✔ Yes — using errors='coerce' is correct
# ✔ Yes — getting NaT is correct since the format is invalid
# ✔ "errors='coerce'" means: replace invalid parsing with NaT

# %% [markdown]
# %H → hour
#
# %M → minute
#
# %S → second
#
# errors='coerce' → invalid entries become NaT

# %%
#✅ How to verify after conversion
df['CheckInDate'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['CheckInDate'].head()
# Out:
# 0   NaT
# 1   NaT
# 2   NaT
# 3   NaT
# 5   NaT
# Name: CheckInDate, dtype: datetime64[ns]

# %%
#verify
df.head(10)
# Out:
#     HotelID          HotelName       Location RoomType  Rating  PricePerNight  \
# 0         1       Mountain Inn          Miami      NaN     5.0          200.0
# 1         2  City Lights Hotel       New York   Double     3.0          100.0
# 2         3         Ocean View          Miami   Double     NaN          100.0
# 3         4  City Lights Hotel    Los Angeles    Suite     3.0          150.0
# 5         6         Royal Stay  San Francisco   Deluxe     4.0          100.0
# 6         7         Ocean View        Chicago   Deluxe     NaN          250.0
# 9        10  City Lights Hotel        Chicago   Deluxe     3.0           50.0
# 10       11       Mountain Inn       New York    Suite     3.0          200.0
# 12       13  City Lights Hotel  San Francisco   Deluxe     5.0          150.0
# 13       14         Royal Stay        Chicago   Single     NaN          200.0
#
#    BookingStatus CheckInDate
# 0      Cancelled         NaT
# 1      Confirmed         NaT
# 2      Cancelled         NaT
# 3      Confirmed         NaT
# 5        Pending         NaT
# 6      Cancelled         NaT
# 9      Cancelled         NaT
# 10       Pending         NaT
# 12     Confirmed         NaT
# 13     Cancelled         NaT

# %% [markdown]
# ✅ What “NaT” Means
#
# NaT stands for:
#
# 🔹 Not a Time
#
# It is the datetime equivalent of NaN.
#
# NaN = missing numeric value
#
# NaT = missing datetime value
#
# So when pandas tries to convert your CheckInDate column into datetime, but cannot understand your string format, it replaces them with NaT.
#
# 1. Your CheckInDate column became NaT because your data has no valid dates
#
# Your original data had values like:
#
# 03:16.8
#
#
# This is NOT a date (YYYY-MM-DD)
# This is not even a proper time format for pandas (HH:MM:SS)
#
# So pandas tried to convert it to a datetime but couldn't → result is:
#
# NaT = Not a Time (missing datetime)
#
# ❓ So the question: Is NaT correct here?
# ✔ YES — NaT is correct because your original data doesn’t contain real dates.
#
# There is no valid date to convert.
#
# Pandas can only give you a datetime if a real date exists.
#
# So NaT simply means:
#
# “This value cannot be understood as a date or time.”
#
# And that is the correct behavior.
#
# ❓ Is NaT beneficial or bad for data cleaning?
#
# ✔ BENEFICIAL
#
# Because:
#
# It clearly marks that your CheckInDate has invalid or missing date values
#
# NaT behaves like NaN — you can filter, drop, fill, or analyze it easily
#
# You can now clean or replace it however you want
#
# ❓ Should you convert the column into a proper datetime?
# ✔ Yes, but only if you know the true date format.
#
# Right now, your dataset does NOT contain real dates.
#
# So transforming it to datetime will always give NaT.

# %%
#5. Extract the year from the CheckInDate column.
df['CheckInDate'] = df['CheckInDate'].dt.year #this is correct syntax but gives error bcz CheckInDate is not correct Date format.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 #5. Extract the year from the CheckInDate column.
# ----> 2 df['CheckInDate'] = df['CheckInDate'].dt.year #this is correct syntax but gives error bcz CheckInDate is not correct Date format.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# In your case:
#
# You converted CheckInDate to string
#
# Then tried to convert to datetime → all values became NaT
#
# Then (earlier) you may have overwritten the column again
#
# So pandas sees the column as non-datetime, therefore .dt does not work.
#
# ⚠️ But there is a bigger issue (important)
# 🚨 Your dataset has NO VALID DATES
#
# All values in CheckInDate are:
#
# NaT
#
#
# So even if .dt.year worked, the result would be:
#
# NaN / NaT
#
#
# There is no year to extract.
#
# ✅ Correct Answer for Question #5 (Conceptually)
# Q: Extract the year from the CheckInDate column
# A: This is only possible if the column contains valid datetime values.
#
# The correct code (when valid dates exist) is:
#
# df['Year'] = df['CheckInDate'].dt.year
#
#
# ⚠️ Notice:
#
# We create a new column Year
#
# We do NOT overwrite CheckInDate

# %% [markdown]
# | Situation                   | Result             |
# | --------------------------- | ------------------ |
# | Column is datetime          | `.dt.year` works   |
# | Column is string/object     | `.dt` fails        |
# | Column is NaT only          | Year = NaN         |
# | Overwriting datetime column | Causes `.dt` error |

# %%
#to overcome this issue, we have to make fake date column
#Step 1 — Convert to string
df['CheckInDate'] = df['CheckInDate'].astype(str)

# %%
#Step 2 — Attach a fake date in front
df['CheckInDate'] = '2023-01-01' + df['CheckInDate']

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus                             CheckInDate
# 0     Cancelled  2023-01-012023-01-01 2023-01-0103:16.8
# 1     Confirmed  2023-01-012023-01-01 2023-01-0103:16.8
# 2     Cancelled  2023-01-012023-01-01 2023-01-0103:16.8
# 3     Confirmed  2023-01-012023-01-01 2023-01-0103:16.8
# 4     Confirmed  2023-01-012023-01-01 2023-01-0103:16.8

# %% [raw]
# Yes — you ran this line multiple times, so the fake date kept getting prepended again and again.

# %%
#Clean the column (remove repeated fake dates)
#We will extract only the time part (03:16.8) and discard everything else.
df['CheckInDate'] = df['CheckInDate'].astype(str).str[-7:]

# %% [markdown]
# Why -7?
#
# "03:16.8" has 7 characters
#
# This safely keeps only the time

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %%
#Add fake date WITH SPACE
df['CheckInDate'] = '2023-01-01 ' + df['CheckInDate']
#Notice the space after 01.

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate
# 0     Cancelled  2023-01-01 03:16.8
# 1     Confirmed  2023-01-01 03:16.8
# 2     Cancelled  2023-01-01 03:16.8
# 3     Confirmed  2023-01-01 03:16.8
# 4     Confirmed  2023-01-01 03:16.8

# %%
#Step 3 — Convert to datetime safely
df['CheckInDate'] = pd.to_datetime(df['CheckInDate'], errors = 'coerce')
#if any error occured in CheckInDate column, this "errors='coerce'" will fix this
#errors='coerce' → invalid entries become NaT

# %%
#Step 4 — Extract Year
df['Year'] = df['CheckInDate'].dt.year

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year
# 0     Cancelled 2023-01-01 03:16:48  2023
# 1     Confirmed 2023-01-01 03:16:48  2023
# 2     Cancelled 2023-01-01 03:16:48  2023
# 3     Confirmed 2023-01-01 03:16:48  2023
# 4     Confirmed 2023-01-01 03:16:48  2023

# %%
#6. Extract the month from the CheckInDate column.
df['Month'] = df['CheckInDate'].dt.month

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month
# 0     Cancelled 2023-01-01 03:16:48  2023      1
# 1     Confirmed 2023-01-01 03:16:48  2023      1
# 2     Cancelled 2023-01-01 03:16:48  2023      1
# 3     Confirmed 2023-01-01 03:16:48  2023      1
# 4     Confirmed 2023-01-01 03:16:48  2023      1

# %%
#7.	Extract the day of the week from the CheckInDate column.
df['WeekDay'] = df['CheckInDate'].dt.day_name()

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month WeekDay
# 0     Cancelled 2023-01-01 03:16:48  2023      1  Sunday
# 1     Confirmed 2023-01-01 03:16:48  2023      1  Sunday
# 2     Cancelled 2023-01-01 03:16:48  2023      1  Sunday
# 3     Confirmed 2023-01-01 03:16:48  2023      1  Sunday
# 4     Confirmed 2023-01-01 03:16:48  2023      1  Sunday

# %%
#8.	Find all records where the RoomsAvailable column has values greater than 150.
#since RoomsAvailable column is not present in the dataset we have to create a fake RoomsAvailable column
df['RoomsAvailable'] = np.random.randint(50, 300, size=len(df))

# %% [markdown]
# #✔ Why we use len(df)
#
# #Because:
#
# #Each row must have exactly one value
#
# #Otherwise pandas will throw an error

# %%
#now Find all records where RoomsAvailable > 150
df[df['RoomsAvailable'] > 150]
# Out:
#     HotelID          HotelName       Location RoomType  Rating  PricePerNight  \
# 1         2  City Lights Hotel       New York   Double     3.0          100.0
# 6         7         Ocean View        Chicago   Deluxe  Medium          250.0
# 7         8         Ocean View          Miami   Single     5.0            NaN
# 8         9         Ocean View        Chicago   Single     5.0          100.0
# 10       11       Mountain Inn       New York    Suite     3.0          200.0
# 11       12         Ocean View        Chicago   Double     5.0          100.0
# 12       13  City Lights Hotel  San Francisco   Deluxe     5.0          150.0
# 15       16         Royal Stay  San Francisco   Deluxe     4.0           50.0
# 16       17       Mountain Inn    Los Angeles   Deluxe  Medium          250.0
# 17       18  City Lights Hotel        Chicago      NaN     4.0          200.0
# 18       19       Grand Palace       New York      NaN     4.0          200.0
# 19       20       Mountain Inn    Los Angeles    Suite  Medium          200.0
# 20       21         Royal Stay    Los Angeles   Double     3.0          250.0
# 21       22  City Lights Hotel          Miami    Suite     5.0          200.0
# 22       23       Mountain Inn  San Francisco    Suite     4.0          250.0
# 23       24       Grand Palace        Chicago    Suite     5.0          200.0
# 29       30       Mountain Inn  San Francisco   Single     5.0          100.0
# 31       32       Mountain Inn  San Francisco      NaN  Medium           50.0
# 33       34       Grand Palace  San Francisco   Double     5.0          200.0
# 35       36  City Lights Hotel        Chicago   Single     3.0          100.0
# 37       38  City Lights Hotel    Los Angeles   Deluxe     4.0          100.0
# 39       40         Royal Stay  San Francisco   Single     4.0           50.0
# 41       42       Grand Palace  San Francisco    Suite     4.0          250.0
# 46       47         Royal Stay          Miami    Suite     3.0          100.0
# 47       48  City Lights Hotel        Chicago   Deluxe     4.0           50.0
# 48       49         Royal Stay    Los Angeles   Deluxe     3.0          250.0
# 51       52       Mountain Inn       New York   Single     3.0          250.0
# 52       53       Mountain Inn       New York   Deluxe     5.0          250.0
# 54       55         Ocean View        Chicago   Single     3.0          150.0
# 55       56       Grand Palace       New York   Double     5.0          200.0
# 56       57       Mountain Inn          Miami   Single     3.0          100.0
# 58       59       Mountain Inn       New York   Double     4.0          250.0
# 62       63  City Lights Hotel  San Francisco   Deluxe     4.0          250.0
# 63       64         Royal Stay       New York    Suite     4.0           50.0
# 64       65         Royal Stay        Chicago    Suite     5.0          200.0
# 67       68         Royal Stay        Chicago    Suite     5.0            NaN
# 68       69       Mountain Inn       New York    Suite     4.0          100.0
# 70       71       Grand Palace       New York   Deluxe     4.0          200.0
# 71       72  City Lights Hotel       New York    Suite     5.0           50.0
# 73       74         Royal Stay          Miami   Deluxe     4.0          100.0
# 74       75  City Lights Hotel          Miami   Double     4.0          100.0
# 75       76         Royal Stay    Los Angeles   Deluxe  Medium          250.0
# 76       77       Grand Palace        Chicago   Single     3.0          200.0
# 78       79       Mountain Inn  San Francisco   Deluxe     3.0          200.0
# 79       80       Mountain Inn       New York    Suite     5.0          100.0
# 80       81  City Lights Hotel       New York   Single     4.0          100.0
# 81       82       Grand Palace        Chicago   Deluxe     5.0          150.0
# 88       89       Mountain Inn       New York   Deluxe     3.0           50.0
# 89       90         Ocean View        Chicago      NaN     3.0          200.0
# 91       92       Grand Palace  San Francisco    Suite     5.0          200.0
# 94       95       Grand Palace          Miami   Double     3.0          150.0
# 95       96         Ocean View        Chicago   Deluxe     4.0          200.0
# 96       97  City Lights Hotel        Chicago   Double     4.0           50.0
# 98       99         Royal Stay  San Francisco   Double     5.0          250.0
#
#    BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 1      Confirmed 2023-01-01 03:16:48  2023      1  Sunday             206
# 6      Cancelled 2023-01-01 03:16:48  2023      1  Sunday             265
# 7      Confirmed 2023-01-01 03:16:48  2023      1  Sunday             177
# 8      Confirmed 2023-01-01 03:16:48  2023      1  Sunday             170
# 10       Pending 2023-01-01 03:16:48  2023      1  Sunday             161
# 11       Pending 2023-01-01 03:16:48  2023      1  Sunday             219
# 12     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             205
# 15     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             244
# 16     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             242
# 17     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             259
# 18       Pending 2023-01-01 03:16:48  2023      1  Sunday             269
# 19     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             258
# 20       Pending 2023-01-01 03:16:48  2023      1  Sunday             206
# 21           NaN 2023-01-01 03:16:48  2023      1  Sunday             237
# 22       Pending 2023-01-01 03:16:48  2023      1  Sunday             232
# 23       Pending 2023-01-01 03:16:48  2023      1  Sunday             223
# 29     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             228
# 31     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             287
# 33     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             240
# 35     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             162
# 37     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             217
# 39     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             267
# 41     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             163
# 46     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             276
# 47     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             297
# 48       Pending 2023-01-01 03:16:48  2023      1  Sunday             170
# 51     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             251
# 52     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             232
# 54     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             162
# 55     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             260
# 56     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             186
# 58     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             248
# 62           NaN 2023-01-01 03:16:48  2023      1  Sunday             157
# 63     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             240
# 64     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             161
# 67     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             200
# 68     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             242
# 70     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             290
# 71     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             173
# 73     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             251
# 74     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             262
# 75       Pending 2023-01-01 03:16:48  2023      1  Sunday             166
# 76     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             184
# 78     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             288
# 79     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             152
# 80     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             213
# 81           NaN 2023-01-01 03:16:48  2023      1  Sunday             162
# 88     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             190
# 89       Pending 2023-01-01 03:16:48  2023      1  Sunday             283
# 91           NaN 2023-01-01 03:16:48  2023      1  Sunday             203
# 94       Pending 2023-01-01 03:16:48  2023      1  Sunday             222
# 95     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             172
# 96     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             172
# 98     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             208

# %%
#Verify it worked
df['RoomsAvailable'].describe()
# Out:
# count    100.000000
# mean     162.930000
# std       70.278415
# min       50.000000
# 25%       99.500000
# 50%      161.500000
# 75%      224.250000
# max      297.000000
# Name: RoomsAvailable, dtype: float64

# %%
#OR--
df[df['RoomsAvailable'] > 150].shape #shape gives (number of rows, numbr of columns)
# Out:
# (54, 12)

# %% [raw]
# What does this mean?
# Value	Meaning
# 54	54 rows satisfy the condition (RoomsAvailable > 150)
# 12	The DataFrame has 12 columns
#
# So:
#
# 54 hotel records have more than 150 rooms available

# %%
#9.	Find the hotels that have a price per night greater than 400.
df[df['PricePerNight']>400]
# Out:
# Empty DataFrame
# Columns: [HotelID, HotelName, Location, RoomType, Rating, PricePerNight, BookingStatus, CheckInDate, Year, Month, WeekDay, RoomsAvailable]
# Index: []

# %%
df['PricePerNight'].value_counts()
# Out:
# PricePerNight
# 250.0    24
# 200.0    23
# 100.0    23
# 50.0     14
# 150.0    11
# Name: count, dtype: int64

# %%
#verify
df[df['PricePerNight']>400].shape #0 rows satisfied the condition >400 price per night
# Out:
# (0, 12)

# %%
#10.	Remove hotels that have null values in the Location column.
#verify how many null values are there in location column
df['Location'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Location, Length: 100, dtype: bool

# %%
#verify how many null values are there in location column
df['Location'].describe()
# Out:
# count          100
# unique           5
# top       New York
# freq            25
# Name: Location, dtype: object

# %%
#verify how many null values are there in location column
df['Location'].value_counts()
# Out:
# Location
# New York         25
# Miami            23
# Chicago          21
# San Francisco    17
# Los Angeles      14
# Name: count, dtype: int64

# %%
#verify how many null values are there in location column
df['Location'].shape
# Out:
# (100,)

# %% [markdown]
# ✅ Meaning:
#
# Location column has 100 rows
#
# The comma means it’s a 1-dimensional object (Series)
#
# So combining both results:
#
# Check	Result
# Total rows	100
# Missing values	100
#
# 👉 100 out of 100 values are NaN

# %%
#Case 1: There are NO null values (your case) (check how manu null values)
df['Location'].isna().sum()
# Out:
# 100

# %%
#well there is not any null values in Location column
#but to remove null value, we use
df['Location'] = df['Location'].dropna(inplace = True)

# %% [markdown]
# I am getting 👉 100 out of 100 values are NaN , this is incorrrect, and this happens becz i used this code letter
# "df['Location'] = df['Location'].dropna(inplace = True)"
# 🧠 Why is this happening?
#
# This usually happens because of earlier incorrect operations, for example:
#
# Assigning a column to the result of dropna(inplace=True)
#
# Overwriting the column accidentally
#
# Running a cleaning command multiple times
#
# Example of the mistake (you did this earlier 👇):
#
# df['Location'] = df['Location'].dropna(inplace=True)
#
# This sets the entire column to None → NaN.

# %%
#Confirm visually
df['Location'].head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: Location, dtype: object

# %% [markdown]
# 🧪 Why does pandas show None instead of NaN?
#
# Because:
#
# Location column has dtype: object
#
# In object columns:
#
# Missing values may appear as None
#
# Or np.nan
#
# Both are considered null by pandas

# %%
df.head()
# Out:
#    HotelID          HotelName Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn     None      NaN     5.0          200.0
# 1        2  City Lights Hotel     None   Double     3.0          100.0
# 2        3         Ocean View     None   Double  Medium          100.0
# 3        4  City Lights Hotel     None    Suite     3.0          150.0
# 4        5  City Lights Hotel     None    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 0     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             143
# 1     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             206
# 2     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             144
# 3     Confirmed 2023-01-01 03:16:48  2023      1  Sunday              59
# 4     Confirmed 2023-01-01 03:16:48  2023      1  Sunday              89

# %% [markdown]
# ⭐ Beginner Rule (VERY IMPORTANT)
# ❌ Never do:
# df['col'] = df['col'].dropna(inplace=True)
#
# ✅ Always do one of these:
# df['col'] = df['col'].fillna(value)
# df.dropna(subset=['col'], inplace=True)
#
# ✅ Final Summary
#
# isna().sum() = 100 → all values missing
#
# .shape = (100,) → 100 rows
#
# Column was accidentally overwritten
#
# Best fix: reload data or fill with a value

# %% [raw]
# ✅ Important truth (beginner rule)
#
# None ≈ NaN in pandas when checking missing values
#
# Functions that treat both the same:
#
# .isna()
#
# .isnull()
#
# .fillna()
#
# .dropna()

# %%
# the location column is currupted now, so instead of replacind it with 'unknown' placeholder, we have to relaod the csv file again
df = pd.read_csv('arbor_hotel_data_pandas.csv')

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HotelID        100 non-null    int64
#  1   HotelName      100 non-null    object
#  2   Location       100 non-null    object
#  3   RoomType       93 non-null     object
#  4   Rating         91 non-null     float64
#  5   PricePerNight  95 non-null     float64
#  6   BookingStatus  89 non-null     object
#  7   CheckInDate    100 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.4+ KB

# %% [markdown]
# 🛡️ Very important habit to build (BEST PRACTICE)
# 🔒 Always keep a backup copy
#
# Before cleaning:

# %%
df_original = df.copy()

# %%
#If something breaks:
df = df_original.copy()
#This will save you hours in the future. #this is temporary save file not permanent

# %% [markdown]
# ❗ What NOT to do now
#
# ❌ Don’t try to “fix” Location by guessing
# ❌ Don’t randomly fill important columns
# ❌ Don’t continue analysis on corrupted data
#
# 🧠 What you learned (this is valuable!)
#
# You learned:
#
# dropna(inplace=True) is dangerous on a column
#
# None and NaN are both missing
#
# How to detect column destruction
#
# When to restart cleanly (real-world skill!)
#
# This is huge progress, not failure.

# %% [raw]
# 🔑 Very important concept (MEMORY vs FILE)
# 🧠 In-memory (temporary)
# df_original = df.copy()
#
#
# Exists only while the notebook/kernel is running
#
# If you restart kernel or reload CSV → ❌ gone
#
# Useful for undo within same session
#
# 💾 On-disk (permanent)
# df.to_csv('cleaned_data.csv', index=False)
#
#
# Saved to disk
#
# Can be reloaded anytime
#
# This is how you preserve your hard work

# %%
#Do the data cleaning from scratch:
#1.	How do you fill missing values in the Rating column with the value "Medium"?
df['Rating'] = df['Rating'].fillna('Medium', inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4996\2938947959.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'] = df['Rating'].fillna('Medium', inplace = True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4996\2938947959.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Medium' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Rating'] = df['Rating'].fillna('Medium', inplace = True)

# %%
#verify
df.head()
# Out:
#    HotelID          HotelName     Location RoomType Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN   None          200.0
# 1        2  City Lights Hotel     New York   Double   None          100.0
# 2        3         Ocean View        Miami   Double   None          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite   None          150.0
# 4        5  City Lights Hotel     New York    Suite   None            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %% [markdown]
# ou did not misunderstand pandas — you discovered a real and subtle trap 👍
# This is one of the most common beginner mistakes, and the confusion is totally justified.
#
# Let’s fix your mental model once and for all.
#
# ❌ Why your code breaks the column
#
# You wrote:
#
# df['Rating'] = df['Rating'].fillna('Medium', inplace=True)
#
# 🔥 What actually happens internally
#
# df['Rating'].fillna(..., inplace=True)
# → modifies the column in place
# → returns None
#
# So Python evaluates this as:
#
# df['Rating'] = None
#
#
# That’s why your entire column becomes None.
#
# 🧠 Key rule (MEMORIZE THIS)
#
# If you use inplace=True, NEVER assign the result to a variable or column.
#
# ✅ Correct ways (pick ONE, not both)
# ✔ Option 1 (RECOMMENDED, modern & safe)
# df['Rating'] = df['Rating'].fillna('Medium')
#
#
# No inplace
#
# Clear
#
# Future-proof
#
# No column corruption
#
# ✔ Option 2 (old style, still valid)
# df['Rating'].fillna('Medium', inplace=True)
#
#
# Do NOT assign it
#
# Direct modification
#
# ❌ What NOT to do (again)
# df['Rating'] = df['Rating'].fillna('Medium', inplace=True)
#
#
# This will always break the column.
#
# ❓ Should you “never use inplace=True”?
# Honest professional answer:
#
# 👉 Yes — you can safely avoid inplace=True completely.
#
# Most professionals prefer:
#
# df[col] = df[col].method()
#
#
# Reasons:
#
# Clear behavior
#
# No silent bugs
#
# Pandas is slowly deprecating inplace=True
#
# Easier to debug

# %%
#redo all cleaning correctly
#STEP 0 — Load raw data & protect it
import pandas as pd
import numpy as np

df_raw = pd.read_csv('arbor_hotel_data_pandas.csv')
df = df_raw.copy()

# %%
#STEP 1 — Quick inspection
df.info
# Out:
# <bound method DataFrame.info of     HotelID          HotelName       Location RoomType  Rating  PricePerNight  \
# 0         1       Mountain Inn          Miami      NaN     5.0          200.0
# 1         2  City Lights Hotel       New York   Double     3.0          100.0
# 2         3         Ocean View          Miami   Double     NaN          100.0
# 3         4  City Lights Hotel    Los Angeles    Suite     3.0          150.0
# 4         5  City Lights Hotel       New York    Suite     3.0            NaN
# ..      ...                ...            ...      ...     ...            ...
# 95       96         Ocean View        Chicago   Deluxe     4.0          200.0
# 96       97  City Lights Hotel        Chicago   Double     4.0           50.0
# 97       98         Royal Stay       New York   Double     5.0            NaN
# 98       99         Royal Stay  San Francisco   Double     5.0          250.0
# 99      100       Grand Palace          Miami   Double     5.0          150.0
#
#    BookingStatus CheckInDate
# 0      Cancelled     03:16.8
# 1      Confirmed     03:16.8
# 2      Cancelled     03:16.8
# 3      Confirmed     03:16.8
# 4      Confirmed     03:16.8
# ..           ...         ...
# 95     Confirmed     03:16.8
# 96     Cancelled     03:16.8
# 97     Cancelled     03:16.8
# 98     Confirmed     03:16.8
# 99     Cancelled     03:16.8
#
# [100 rows x 8 columns]>

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double     NaN          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %%
#STEP 2 — Clean Rating column
#Fill missing values with "Medium" (as per your question)
df['Rating'] = df['Rating'].fillna('Medium')

# %% [raw]
# ✔ Safe
# ✔ No inplace=True
# ✔ No corruption

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus CheckInDate
# 0     Cancelled     03:16.8
# 1     Confirmed     03:16.8
# 2     Cancelled     03:16.8
# 3     Confirmed     03:16.8
# 4     Confirmed     03:16.8

# %%
#STEP 3 — Clean HotelName
#2.	Replace missing values in the CustomerName column with "Guest".
df['HotelName'] = df['HotelName'].fillna('Guest')

# %%
#verify
df['HotelName'].value_counts()
# Out:
# HotelName
# Mountain Inn         26
# Royal Stay           21
# City Lights Hotel    19
# Grand Palace         18
# Ocean View           16
# Name: count, dtype: int64

# %%
#STEP 4 — Remove duplicate rows (if any)
#3.	Identify and remove any duplicate records from the dataset.
df = df.drop_duplicates()

# %%
#verify
df.duplicated().sum()
# Out:
# 0

# %%
#STEP 5 — Handle CheckInDate (add fake date for practice)
#4.	Convert the CheckInDate column to a proper datetime format.
df['CheckInDate'] = df['CheckInDate'].astype(str) #convert this column to string

# %%
df['CheckInDate'] = pd.to_datetime( '2023-01-01 ' + df['CheckInDate'], errors = 'coerce')

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate
# 0     Cancelled 2023-01-01 03:16:48
# 1     Confirmed 2023-01-01 03:16:48
# 2     Cancelled 2023-01-01 03:16:48
# 3     Confirmed 2023-01-01 03:16:48
# 4     Confirmed 2023-01-01 03:16:48

# %%
#STEP 6 — Extract date parts
#5.	Extract the year from the CheckInDate column.
df['Year'] = df['CheckInDate'].dt.year

# %%
#6.	Extract the month from the CheckInDate column.
df['Month'] = df['CheckInDate'].dt.month

# %%
#7.	Extract the day of the week from the CheckInDate column.
df['WeekDay'] = df['CheckInDate'].dt.day_name()

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month WeekDay
# 0     Cancelled 2023-01-01 03:16:48  2023      1  Sunday
# 1     Confirmed 2023-01-01 03:16:48  2023      1  Sunday
# 2     Cancelled 2023-01-01 03:16:48  2023      1  Sunday
# 3     Confirmed 2023-01-01 03:16:48  2023      1  Sunday
# 4     Confirmed 2023-01-01 03:16:48  2023      1  Sunday

# %%
#8.	Find all records where the RoomsAvailable column has values greater than 150.
#since RoomsAvailable column is not available in dataset , for practice we can create fake column
df['RoomsAvailable'] = np.random.randint(50, 300, len(df))

# %%
#STEP 9 — Filter rooms > 150 (Question #8)
df[df['RoomsAvailable'] > 150]
# Out:
#     HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0         1       Mountain Inn        Miami      NaN     5.0          200.0
# 1         2  City Lights Hotel     New York   Double     3.0          100.0
# 6         7         Ocean View      Chicago   Deluxe  Medium          250.0
# 8         9         Ocean View      Chicago   Single     5.0          100.0
# 10       11       Mountain Inn     New York    Suite     3.0          200.0
# ..      ...                ...          ...      ...     ...            ...
# 92       93         Ocean View        Miami   Single     3.0          200.0
# 93       94         Ocean View  Los Angeles   Single     3.0          100.0
# 96       97  City Lights Hotel      Chicago   Double     4.0           50.0
# 97       98         Royal Stay     New York   Double     5.0            NaN
# 99      100       Grand Palace        Miami   Double     5.0          150.0
#
#    BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 0      Cancelled 2023-01-01 03:16:48  2023      1  Sunday             206
# 1      Confirmed 2023-01-01 03:16:48  2023      1  Sunday             281
# 6      Cancelled 2023-01-01 03:16:48  2023      1  Sunday             257
# 8      Confirmed 2023-01-01 03:16:48  2023      1  Sunday             218
# 10       Pending 2023-01-01 03:16:48  2023      1  Sunday             255
# ..           ...                 ...   ...    ...     ...             ...
# 92       Pending 2023-01-01 03:16:48  2023      1  Sunday             275
# 93     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             282
# 96     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             266
# 97     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             216
# 99     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             248
#
# [64 rows x 12 columns]

# %%
#verify
df['RoomsAvailable'].shape
# Out:
# (100,)

# %% [raw]
# output: (100, ) means 100 rows with 1-dimension in RoomAvailable column

# %%
df[df['RoomsAvailable'] > 150].shape #64 rows with value greater than 150 and 12 columns
# Out:
# (64, 12)

# %%
#9.	Find the hotels that have a price per night greater than 400.
df[df['PricePerNight'] > 400] #mean no hotel with >40 price per night
# Out:
# Empty DataFrame
# Columns: [HotelID, HotelName, Location, RoomType, Rating, PricePerNight, BookingStatus, CheckInDate, Year, Month, WeekDay, RoomsAvailable]
# Index: []

# %%
df['PricePerNight'].value_counts()
# Out:
# PricePerNight
# 250.0    24
# 200.0    23
# 100.0    23
# 50.0     14
# 150.0    11
# Name: count, dtype: int64

# %%
df[df['PricePerNight']>400].shape
# Out:
# (0, 12)

# %%
#before remove hotels that have null value in location column, firstly:
#STEP 10 — SAVE your cleaned dataset (VERY IMPORTANT)
df.to_csv('hotel_data_cleaned.csv', index = False)

# %% [raw]
# index=False means:
#
# Do NOT save the DataFrame’s index as a column in the CSV file
#
# ❌ If you do NOT use index=False
# df.to_csv('hotel_data_cleaned.csv')
#
#
# Your CSV will look like this:
#
# ,index,HotelID,HotelName,Location,...
# 0,1,Mountain Inn,Miami,...
# 1,2,City Lights Hotel,New York,...
#
#
# That extra column (0,1,2,…) is useless and confusing.

# %%
#10. Remove hotels that have null values in the Location column.
#Step 1 — First, CHECK if nulls exist (always do this)
df['Location'].isna().sum()
# Out:
# 0

# %% [markdown]
# 0 → No rows to remove
#
# > 0 → Some rows must be removed

# %%
#Step 2 — Remove rows where Location is null (CORRECT WAY)
df = df.dropna(subset= ['Location'])

# %% [raw]
# ❌ What NOT to do (important)
# df['Location'] = df['Location'].dropna(inplace=True)  # ❌ WRONG
#
#
# This destroys the column (you experienced this already).

# %% [markdown]
# | Task                   | Correct Method                    |
# | ---------------------- | --------------------------------- |
# | Remove rows with nulls | `df.dropna(subset=[...])`         |
# | Fill nulls             | `df[col] = df[col].fillna(value)` |
# | Check nulls            | `df[col].isna().sum()`            |

# %% [markdown]
# # Date-Based Questions

# %%
#11.	Find all hotels where the check-in date is in the year 2023.
hotels_2023 = df[df['CheckInDate'].dt.year == 2023]

# %%
#Verify it worked'
hotels_2023.shape
# Out:
# (100, 12)

# %%
hotels_2023.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 0     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             206
# 1     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             281
# 2     Cancelled 2023-01-01 03:16:48  2023      1  Sunday              61
# 3     Confirmed 2023-01-01 03:16:48  2023      1  Sunday              89
# 4     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             149

# %%
df.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 0     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             206
# 1     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             281
# 2     Cancelled 2023-01-01 03:16:48  2023      1  Sunday              61
# 3     Confirmed 2023-01-01 03:16:48  2023      1  Sunday              89
# 4     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             149

# %% [raw]
# can you tell me the basic difference: df[df['CheckInDate']].dt.year and df['CheckInDate'].dt.year
# Think of df like a table
#
# Rows = hotel records
#
# Columns = HotelName, Location, CheckInDate, etc.
#
# ✅ Case 1 (CORRECT)
# df['CheckInDate'].dt.year
#
# What this means (VERY SIMPLE):
#
# “Go to the CheckInDate column and take the year from each value.”
#
# Result:
#
# A list (Series) like:
#
# 2023
# 2023
# 2023
# ...
#
#
# ✔ Correct
# ✔ Safe
# ✔ What you want
#
# ❌ Case 2 (WRONG)
# df[df['CheckInDate']].dt.year
#
# What this actually means to pandas:
#
# “Use the values inside CheckInDate as column names and select them from the DataFrame.”
#
# But your DataFrame columns are named like:
#
# HotelID, HotelName, Location, ...
# NOT:
#
# yaml
# Copy code
# 2023-01-01 03:16:48
# So pandas gets confused and throws an error.

# %% [markdown]
# | Code                | Meaning                                        |
# | ------------------- | ---------------------------------------------- |
# | `df['CheckInDate']` | Open one column                                |
# | `.dt.year`          | Take year from each value                      |
# | `df[ something ]`   | Select rows (if boolean) or columns (if names) |

# %%
#12.	Find hotels where the check-in date falls on a weekend (Saturday or Sunday).
weekend_hotels = df[df['WeekDay'].isin(['Saturday', 'Sunday'])]

# %%
#verify
weekend_hotels.shape
# Out:
# (100, 12)

# %%
weekend_hotels.head()
# Out:
#    HotelID          HotelName     Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn        Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel     New York   Double     3.0          100.0
# 2        3         Ocean View        Miami   Double  Medium          100.0
# 3        4  City Lights Hotel  Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel     New York    Suite     3.0            NaN
#
#   BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 0     Cancelled 2023-01-01 03:16:48  2023      1  Sunday             206
# 1     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             281
# 2     Cancelled 2023-01-01 03:16:48  2023      1  Sunday              61
# 3     Confirmed 2023-01-01 03:16:48  2023      1  Sunday              89
# 4     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             149

# %% [markdown]
# #📌 One-line comparison
# | Code                            | Result          |
# | ------------------------------- | --------------- |
# | `df['WeekDay'].isin([...])`     | True/False list |
# | `df[df['WeekDay'].isin([...])]` | Filtered rows   |

# %%
df['WeekDay'].isin(['Saturday', 'Sunday'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: WeekDay, Length: 100, dtype: bool

# %%
#13.	Find the total number of check-ins for each month.
df.groupby('Month').size()
# Out:
# Month
# 1    100
# dtype: int64

# %% [raw]
# This means:
#
# 100 check-ins happened in January

# %%
#Cleaner output (with column name)
df.groupby('Month').size().reset_index(name = 'TotalCheckIns')
# Out:
#    Month  TotalCheckIns
# 0      1            100

# %% [markdown]
# 🧠 Explanation (VERY SIMPLE)
# Step by step:
#
# groupby('Month') → group rows by month
#
# .size() → count how many rows in each group
#
# Each row = one check-in

# %%
#14.	Find the number of hotels checked in per city.
df.groupby('Location').size()
# Out:
# Location
# Chicago          21
# Los Angeles      14
# Miami            23
# New York         25
# San Francisco    17
# dtype: int64

# %%
##Cleaner output (with column name)
df.groupby('Location').size().reset_index(name = 'Number_of_hotels')
# Out:
#         Location  Number_of_hotels
# 0        Chicago                21
# 1    Los Angeles                14
# 2          Miami                23
# 3       New York                25
# 4  San Francisco                17

# %%
#15.	Count the total number of hotels checked in each year.
df.groupby('Year')['HotelID'].count()
# Out:
# Year
# 2023    100
# Name: HotelID, dtype: int64

# %%
#OR--
df.groupby('Year').size().reset_index(name = 'Total_hotels')
# Out:
#    Year  Total_hotels
# 0  2023           100

# %%
#16.	Find the highest price per night for each location.
df.groupby('Location')['PricePerNight'].max()
# Out:
# Location
# Chicago          250.0
# Los Angeles      250.0
# Miami            250.0
# New York         250.0
# San Francisco    250.0
# Name: PricePerNight, dtype: float64

# %%
#OR--
df.groupby('Location')['PricePerNight'].max().reset_index(name = 'MaxPricePerNight')
# Out:
#         Location  MaxPricePerNight
# 0        Chicago             250.0
# 1    Los Angeles             250.0
# 2          Miami             250.0
# 3       New York             250.0
# 4  San Francisco             250.0

# %%
#17.	Find the hotel with the most available rooms.
#Step 1 — Get the maximum rooms available
df['RoomsAvailable'].max()
# Out:
# 296

# %%
#Step 2 — Get the hotel(s) with that maximum value
df[df['RoomsAvailable'] == df['RoomsAvailable'].max()]

#This returns the full row(s) of the hotel(s) with the most rooms.
# Out:
#     HotelID          HotelName       Location RoomType  Rating  PricePerNight  \
# 28       29       Mountain Inn  San Francisco   Single     3.0          200.0
# 75       76         Royal Stay    Los Angeles   Deluxe  Medium          250.0
# 82       83  City Lights Hotel       New York   Deluxe     3.0          100.0
#
#    BookingStatus         CheckInDate  Year  Month WeekDay  RoomsAvailable
# 28       Pending 2023-01-01 03:16:48  2023      1  Sunday             296
# 75       Pending 2023-01-01 03:16:48  2023      1  Sunday             296
# 82     Confirmed 2023-01-01 03:16:48  2023      1  Sunday             296

# %%
#Show only hotel name and rooms
df.loc[df['RoomsAvailable'].idxmax(), ['HotelName', 'RoomsAvailable']]
# Out:
# HotelName         Mountain Inn
# RoomsAvailable             296
# Name: 28, dtype: object

# %% [markdown]
# | Task                 | Code                           |
# | -------------------- | ------------------------------ |
# | Find max value       | `df[col].max()`                |
# | Find row with max    | `df[df[col] == df[col].max()]` |
# | Find single best row | `df.loc[df[col].idxmax()]`     |

# %%
#18.	Find the average rating of hotels per city.
#df.groupby('Location')['Rating'].mean()

#this code wont work bcz already the Rating column has numeric +  string data(NaN-- placed with 'Medium') in it. 
#🧠 Very important rule (MEMORIZE THIS)

#Mathematical operations (mean, sum, max) require numeric data

df['Rating_numeric'] = df['Rating'].replace('Medium', 3)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4996\372467863.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Rating_numeric'] = df['Rating'].replace('Medium', 3)

# %%
#and then find mean
df.groupby('Location')['Rating_numeric'].mean()
# Out:
# Location
# Chicago          3.904762
# Los Angeles      3.571429
# Miami            3.869565
# New York         4.000000
# San Francisco    4.176471
# Name: Rating_numeric, dtype: float64

# %%
#19.	Find all hotels where the check-in date is in December.
df[df['CheckInDate'].dt.month == 12]
# Out:
# Empty DataFrame
# Columns: [HotelID, HotelName, Location, RoomType, Rating, PricePerNight, BookingStatus, CheckInDate, Year, Month, WeekDay, RoomsAvailable, Rating_numeric]
# Index: []

# %%
#How to verify this quickly'
df['CheckInDate'].dt.month.value_counts()
# Out:
# CheckInDate
# 1    100
# Name: count, dtype: int64

# %% [markdown]
# ✅ So what do 1 and 100 mean?
# Value	Meaning
# 1	Month number 1 → January
# 100	There are 100 check-in records in January
#
# So the output means:
#
# All 100 hotel check-ins happened in January.

# %%
#want it as dataframe
df['CheckInDate'].dt.month.value_counts().reset_index(name = 'CheckIn_December')
# Out:
#    CheckInDate  CheckIn_December
# 0            1               100

# %%
df['CheckInDate'].dt.month.value_counts().reset_index(
    name='TotalCheckIns'
).rename(columns={'index': 'Month'})
# Out:
#    CheckInDate  TotalCheckIns
# 0            1            100

# %%
#20.	Export the cleaned dataset into a new CSV file.
df.to_csv('modified_hotel_data_set_arbor', index = False)

# %%
#relaod it
df_check = pd.read_csv('modified_hotel_data_set_arbor')
df_check.head(10)
# Out:
#    HotelID          HotelName       Location RoomType  Rating  PricePerNight  \
# 0        1       Mountain Inn          Miami      NaN     5.0          200.0
# 1        2  City Lights Hotel       New York   Double     3.0          100.0
# 2        3         Ocean View          Miami   Double  Medium          100.0
# 3        4  City Lights Hotel    Los Angeles    Suite     3.0          150.0
# 4        5  City Lights Hotel       New York    Suite     3.0            NaN
# 5        6         Royal Stay  San Francisco   Deluxe     4.0          100.0
# 6        7         Ocean View        Chicago   Deluxe  Medium          250.0
# 7        8         Ocean View          Miami   Single     5.0            NaN
# 8        9         Ocean View        Chicago   Single     5.0          100.0
# 9       10  City Lights Hotel        Chicago   Deluxe     3.0           50.0
#
#   BookingStatus          CheckInDate  Year  Month WeekDay  RoomsAvailable  \
# 0     Cancelled  2023-01-01 03:16:48  2023      1  Sunday             206
# 1     Confirmed  2023-01-01 03:16:48  2023      1  Sunday             281
# 2     Cancelled  2023-01-01 03:16:48  2023      1  Sunday              61
# 3     Confirmed  2023-01-01 03:16:48  2023      1  Sunday              89
# 4     Confirmed  2023-01-01 03:16:48  2023      1  Sunday             149
# 5       Pending  2023-01-01 03:16:48  2023      1  Sunday             107
# 6     Cancelled  2023-01-01 03:16:48  2023      1  Sunday             257
# 7     Confirmed  2023-01-01 03:16:48  2023      1  Sunday             134
# 8     Confirmed  2023-01-01 03:16:48  2023      1  Sunday             218
# 9     Cancelled  2023-01-01 03:16:48  2023      1  Sunday             135
#
#    Rating_numeric
# 0             5.0
# 1             3.0
# 2             3.0
# 3             3.0
# 4             3.0
# 5             4.0
# 6             3.0
# 7             5.0
# 8             5.0
# 9             3.0
